# %%
import calendar
import datetime

# %%
#datetime.datetime(2025,02,29)
datetime.datetime(2025,3,29)
# Out:
# datetime.datetime(2025, 3, 29, 0, 0)

# %%
print( calendar.monthrange(2026, 4) )
# Out:
# (2, 30)
